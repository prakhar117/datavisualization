# %% [markdown]
# <a href="https://colab.research.google.com/github/prakhar117/datavisualization/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(3*4)
# Out:
# 12

# %%
import pandas as pd

# %%
data=pd.read_csv(http://13.234.66.67/summer19/datasets/customer.csv)
# Out:
#   File "<ipython-input-3-96a8f69285c9>", line 1
#     data=pd.read_csv(http://13.234.66.67/summer19/datasets/customer.csv)
#                          ^
# SyntaxError: invalid syntax

# %%
data=pd.read_csv('http://13.234.66.67/summer19/datasets/customer.csv')

# %%
# checking rows and columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# CustomerID                200 non-null int64
# Genre                     200 non-null object
# Age                       200 non-null int64
# Annual Income (k$)        200 non-null int64
# Spending Score (1-100)    200 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
# printing top 5 rows only
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#data # printing all data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
data['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-bdf3e9db6c24> in <module>()
# ----> 1 data['age']
#
# ...

# %%
# any particular column
data['Age']
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
# 5      22
# 6      35
# 7      23
# 8      64
# 9      30
# 10     67
# 11     35
# 12     58
# 13     24
# 14     37
# 15     22
# 16     35
# 17     20
# 18     52
# 19     35
# 20     35
# 21     25
# 22     46
# 23     31
# 24     54
# 25     29
# 26     45
# 27     35
# 28     40
# 29     23
#        ..
# 170    40
# 171    28
# 172    36
# 173    36
# 174    52
# 175    30
# 176    58
# 177    27
# 178    59
# 179    35
# 180    37
# 181    32
# 182    46
# 183    29
# 184    41
# 185    30
# 186    54
# 187    28
# 188    41
# 189    36
# 190    34
# 191    32
# 192    33
# 193    38
# 194    47
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
data['Age'].min()
# Out:
# 18

# %%
data['Age'].max()
data['Age'].mean()
# Out:
# 38.85

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# range of columns
data.iloc[0,1]
data.iloc[0:,1:3]
# Out:
#       Genre  Age
# 0      Male   19
# 1      Male   21
# 2    Female   20
# 3    Female   23
# 4    Female   31
# 5    Female   22
# 6    Female   35
# 7    Female   23
# 8      Male   64
# 9    Female   30
# 10     Male   67
# 11   Female   35
# 12   Female   58
# 13   Female   24
# 14     Male   37
# 15     Male   22
# 16   Female   35
# 17     Male   20
# 18     Male   52
# 19   Female   35
# 20     Male   35
# 21     Male   25
# 22   Female   46
# 23     Male   31
# 24   Female   54
# 25     Male   29
# 26   Female   45
# 27     Male   35
# 28   Female   40
# 29   Female   23
# ..      ...  ...
# 170    Male   40
# 171    Male   28
# 172    Male   36
# 173    Male   36
# 174  Female   52
# 175  Female   30
# 176    Male   58
# 177    Male   27
# 178    Male   59
# 179    Male   35
# 180  Female   37
# 181  Female   32
# 182    Male   46
# 183  Female   29
# 184  Female   41
# 185    Male   30
# 186  Female   54
# 187    Male   28
# 188  Female   41
# 189  Female   36
# ...

# %%
data.iloc[0,1:]
# Out:
# Genre                     Male
# Age                         19
# Annual Income (k$)          15
# Spending Score (1-100)      39
# Name: 0, dtype: object

# %%
data.iloc[0:,[1,3]]
# Out:
#       Genre  Annual Income (k$)
# 0      Male                  15
# 1      Male                  15
# 2    Female                  16
# 3    Female                  16
# 4    Female                  17
# 5    Female                  17
# 6    Female                  18
# 7    Female                  18
# 8      Male                  19
# 9    Female                  19
# 10     Male                  19
# 11   Female                  19
# 12   Female                  20
# 13   Female                  20
# 14     Male                  20
# 15     Male                  20
# 16   Female                  21
# 17     Male                  21
# 18     Male                  23
# 19   Female                  23
# 20     Male                  24
# 21     Male                  24
# 22   Female                  25
# 23     Male                  25
# 24   Female                  28
# 25     Male                  28
# 26   Female                  28
# 27     Male                  28
# ...

# %%
# all description
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# now importing data visualisation libarary
import seaborn as sb

# %%
# count amd plot age column
sb.countplot(data['Age'])

# %%
# ploting all the columns
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffab6251d68>,
# ...
#       dtype=object)

# %%
# lets go back to our bachpan
import matplotlib.pyplot as plt

# %%
distance=[5,12,9]# this is in km
time=[2,5,7] # this is time taken by us in hour
# above data is for prabal seth only

distance1=[5,12,9]# this is in km
time1=[1,8,5] # this is time taken by us in hour
# above data is for harsh seth only

# %%
# now designing x axis 
plt.xlabel("distance")
plt.ylabel("time")
'''
plt.scatter(distance,time,label="prabal performance") # to show dots only
plt.scatter(distance1,time1,label="harsh performance") 
plt.plot(distance,time)   # to show lines only
plt.plot(distance1,time1)
'''
plt.bar(distance,time)
plt.grid(color='green')
plt.legend()
plt.show()
 #showing graph
# Out:
# No handles with labels found to put in legend.
